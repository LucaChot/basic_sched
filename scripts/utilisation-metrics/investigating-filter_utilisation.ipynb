# %% [markdown]
# # Displaying the /proc/pressure based metrics

# %%
# Loading event json
import json

# Plotting the timeline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# %% [markdown]
# ## Baseline

# %%
with open('util-normal.txt', 'r') as file:
    filtered = [line.rstrip('\n') for line in file if "(filter-metrics)" in line]

# %%
data = {}
data['time'] = [line.split()[1] for line in filtered]
data['CPU Utilisation'] = [float(line.split()[4]) for line in filtered]
data['Memory Utilisation'] = [float(line.split()[6]) for line in filtered]

# %%
# 1. Parse time strings into datetime objects
time_objects = [datetime.strptime(t, "%H:%M:%S.%f") for t in data['time']]
start = time_objects[0]
time_objects = [(time - start).total_seconds() for time in time_objects]

# For plotting, matplotlib often works best with a reference date
# and the time difference from that date. Let's pick an arbitrary date.
#reference_date = datetime(1970, 1, 1)
#x_values = [(t - reference_date).total_seconds() for t in time_objects]

# Alternatively, matplotlib can often handle datetime objects directly on the x-axis
# if you format the plot correctly. Let's demonstrate that approach as it's more common.

# 2. Create the plot using matplotlib
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.rcParams['font.size'] = 20  

for key in data.keys():
    if key == 'time':
        continue
    plt.plot(time_objects, data[key], label=key, alpha=.8)
#plt.plot(time_objects, data['cpu some'], linestyle='-')

# Customize the plot
plt.xlabel("Elapsed Time (s)")
plt.ylabel("Resource Utilisation [0-1]")
# plt.title("Investigating Utilisation Metrics when Running a Single Pod")
plt.grid(True)
plt.legend()
# plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Display the plot
plt.savefig('../figures/filter-utilisation-baseline.pdf')
plt.show()

# %% [markdown]
# ## Single

# %%
with open('util-single.txt', 'r') as file:
    filtered = [line.rstrip('\n') for line in file if "(filter-metrics)" in line]

# %%
data = {}
data['time'] = [line.split()[1] for line in filtered]
data['CPU Utilisation'] = [float(line.split()[4]) for line in filtered]
data['Memory Utilisation'] = [float(line.split()[6]) for line in filtered]

# %%
with open('util-single.txt', 'r') as file:
    events = [line.rstrip('\n') for line in file if "(container)" in line]

# %%
events_dict = {}
events_dict['create'] = [line.split()[1] for line in events if "ContainerCreate" in line]
events_dict['start'] = [line.split()[1] for line in events if "TaskStart" in line]
events_dict['exit'] = [line.split()[1] for line in events if "TaskExit" in line]
events_dict['delete'] = [line.split()[1] for line in events if "TaskDelete" in line]

# %%
# 1. Parse time strings into datetime objects
time_objects = [datetime.strptime(t, "%H:%M:%S.%f") for t in data['time']]
start = time_objects[0]
time_objects = [(time - start).total_seconds() for time in time_objects]

# For plotting, matplotlib often works best with a reference date
# and the time difference from that date. Let's pick an arbitrary date.
#reference_date = datetime(1970, 1, 1)
#x_values = [(t - reference_date).total_seconds() for t in time_objects]

# Alternatively, matplotlib can often handle datetime objects directly on the x-axis
# if you format the plot correctly. Let's demonstrate that approach as it's more common.

# 2. Create the plot using matplotlib
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.rcParams['font.size'] = 20  

for key in data.keys():
    if key == 'time':
        continue
    plt.plot(time_objects, data[key], label=key, alpha=.8)
#plt.plot(time_objects, data['cpu some'], linestyle='-')

count = 0
for event in events_dict.keys():
    # Assuming events[event] is a list of time strings for that event
    event_times_objects = [datetime.strptime(t, "%H:%M:%S.%f") for t in events_dict[event]]
    event_times_objects = [(time - start).total_seconds() for time in event_times_objects]
    for event_time_obj in event_times_objects:
        plt.axvline(x=event_time_obj, color='red', alpha=0.5, linestyle=(0, (8, 8)), linewidth=1, label= 'ContainerD Event' if count == 0 else "")
        count += 1

# Customize the plot
plt.xlabel("Elapsed Time (s)")
plt.ylabel("Resource Utilisation [0-1]")
# plt.title("Investigating Filtered Utilisation Metrics when Running a Single Pod")
plt.grid(True)
plt.legend()
# plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Display the plot
plt.savefig('../figures/filter-utilisation-single.pdf')
plt.show()

# %% [markdown]
# ## Small Churn - 5 Pods

# %%
with open('util-smallbatch.txt', 'r') as file:
    filtered = [line.rstrip('\n') for line in file if "(filter-metrics)" in line]

# %%
data = {}
data['time'] = [line.split()[1] for line in filtered]
data['CPU Utilisation'] = [float(line.split()[4]) for line in filtered]
data['Memory Utilisation'] = [float(line.split()[6]) for line in filtered]

# %%
with open('util-smallbatch.txt', 'r') as file:
    events = [line.rstrip('\n') for line in file if "(container)" in line]

# %%
events_dict = {}
events_dict['create'] = [line.split()[1] for line in events if "ContainerCreate" in line]
events_dict['start'] = [line.split()[1] for line in events if "TaskStart" in line]
events_dict['exit'] = [line.split()[1] for line in events if "TaskExit" in line]
events_dict['delete'] = [line.split()[1] for line in events if "TaskDelete" in line]

# %%
# 1. Parse time strings into datetime objects
time_objects = [datetime.strptime(t, "%H:%M:%S.%f") for t in data['time']]
start = time_objects[0]
time_objects = [(time - start).total_seconds() for time in time_objects]

# For plotting, matplotlib often works best with a reference date
# and the time difference from that date. Let's pick an arbitrary date.
#reference_date = datetime(1970, 1, 1)
#x_values = [(t - reference_date).total_seconds() for t in time_objects]

# Alternatively, matplotlib can often handle datetime objects directly on the x-axis
# if you format the plot correctly. Let's demonstrate that approach as it's more common.

# 2. Create the plot using matplotlib
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.rcParams['font.size'] = 20  

for key in data.keys():
    if key == 'time':
        continue
    plt.plot(time_objects, data[key], label=key, alpha=.8)
#plt.plot(time_objects, data['cpu some'], linestyle='-')

count = 0
for event in events_dict.keys():
    # Assuming events[event] is a list of time strings for that event
    event_times_objects = [datetime.strptime(t, "%H:%M:%S.%f") for t in events_dict[event]]
    event_times_objects = [(time - start).total_seconds() for time in event_times_objects]
    for event_time_obj in event_times_objects:
        plt.axvline(x=event_time_obj, color='red', alpha=0.5, linestyle=(0, (8, 8)), linewidth=1, label= 'ContainerD Event' if count == 0 else "")
        count += 1

# Customize the plot
plt.xlabel("Elapsed Time (s)")
plt.ylabel("Resource Utilisation [0-1]")
# plt.title("Investigating Filtered Utilisation Metrics when Running a Batch of 5 Pods")
plt.grid(True)
plt.legend()
# plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Display the plot
plt.savefig('../figures/filter-utilisation-smallbatch.pdf')
plt.show()

# %% [markdown]
# ## Churn - 10 Pods

# %%
with open('util-batch.txt', 'r') as file:
    filtered = [line.rstrip('\n') for line in file if "(metrics)" in line]

# %%
data = {}
data['time'] = [line.split()[1] for line in filtered]
data['CPU Utilisation'] = [float(line.split()[4]) for line in filtered]
data['Memory Utilisation'] = [float(line.split()[6]) for line in filtered]

# %%
with open('util-batch.txt', 'r') as file:
    events = [line.rstrip('\n') for line in file if "(container)" in line]

# %%
events_dict = {}
events_dict['create'] = [line.split()[1] for line in events if "ContainerCreate" in line]
events_dict['start'] = [line.split()[1] for line in events if "TaskStart" in line]
events_dict['exit'] = [line.split()[1] for line in events if "TaskExit" in line]
events_dict['delete'] = [line.split()[1] for line in events if "TaskDelete" in line]

# %%
# 1. Parse time strings into datetime objects
time_objects = [datetime.strptime(t, "%H:%M:%S.%f") for t in data['time']]
start = time_objects[0]
time_objects = [(time - start).total_seconds() for time in time_objects]

# For plotting, matplotlib often works best with a reference date
# and the time difference from that date. Let's pick an arbitrary date.
#reference_date = datetime(1970, 1, 1)
#x_values = [(t - reference_date).total_seconds() for t in time_objects]

# Alternatively, matplotlib can often handle datetime objects directly on the x-axis
# if you format the plot correctly. Let's demonstrate that approach as it's more common.

# 2. Create the plot using matplotlib
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.rcParams['font.size'] = 20  

for key in data.keys():
    if key == 'time':
        continue
    plt.plot(time_objects, data[key], label=key, alpha=.8)
#plt.plot(time_objects, data['cpu some'], linestyle='-')

count = 0
for event in events_dict.keys():
    # Assuming events[event] is a list of time strings for that event
    event_times_objects = [datetime.strptime(t, "%H:%M:%S.%f") for t in events_dict[event]]
    event_times_objects = [(time - start).total_seconds() for time in event_times_objects]
    for event_time_obj in event_times_objects:
        plt.axvline(x=event_time_obj, color='red', alpha=0.5, linestyle=(0, (8, 8)), linewidth=1, label= 'ContainerD Event' if count == 0 else "")
        count += 1

# Customize the plot
plt.xlabel("Elapsed Time (s)")
plt.ylabel("Resource Utilisation [0-1]")
# plt.title("Investigating Filtered Utilisation Metrics when Running a Batch of 10 Pods")
plt.grid(True)
plt.legend()
# plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping

# Display the plot
plt.savefig('../figures/utilisation-bigbatch.pdf')
plt.show()
