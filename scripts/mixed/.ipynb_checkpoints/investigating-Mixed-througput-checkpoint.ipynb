# %% [markdown]
# # Investigating Pi(2000) Throughput

# %%
# Loading event json
import json
import math
# Plotting the timeline
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# %% [markdown]
# CPU-Centric:
#
# Memory-Centric:
#
# Mixed-Centric:
#
# Spazio:
# - Start = 1748364944
# - End = 1748365030
#
# Kube:
# - Start = 1748374847
# - End = 1748374940

# %%
experiments = {
    'spazio-mixed' : {
        'start' : 1748364944,
        'end' : 1748365030,
        'Name' : 'CARICO',
        'drop' : '10.244.23.28:32000'
    },
    'kube-mixed' : {
        'start' : 1748374847,
        'end' : 1748374940,
        'Name' : 'Default Scheduler',
        'drop' : '10.244.23.28:32000'
    }
}
keys = ['kube-mixed-ml', 'spazio-mixed-ml','kube-mixed-pi', 'spazio-mixed-pi']

# %%
exp = 'spazio-mixed'

# %% [markdown]
# ## Pod Completion

# %%
def read_df(filepath):
    try:
        df = pd.read_csv(filepath)
        df = df.drop(columns=['Time'])
    
        # df.index = pd.to_datetime(df.index, errors='coerce')
        # df.info()

        return df
    except FileNotFoundError:
        print(f"Error: The file '{filepath}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
df = pd.read_csv(f'{exp}-pi-pod-completion.csv')

# %%
# df = pd.read_csv()
#  # This will be a pandas Series
plt.rcParams['font.size'] = 20

blue_shades = plt.cm.Blues(np.linspace(0.4, 0.9, 4))
custom_colors = {
    'kube-mixed-pi': plt.cm.Blues(0.75),
    'kube-mixed-ml': plt.cm.Blues(0.75),
    'Default (3000Mi)': blue_shades[2],
    'Default (4000Mi)': blue_shades[3],
    'spazio-mixed-pi': 'mediumseagreen',
    'spazio-mixed-ml': 'mediumseagreen'
}

# --- Define Custom Legend Labels ---
# Mapping internal scheduler names to user-friendly legend labels
legend_labels = {
    'kube-mixed-pi': 'kube-scheduler',
    'kube-mixed-ml': 'kube-scheduler',
    'Default (3000Mi)': 'kube-scheduler (3000Mi Memory)',
    'Default (4000Mi)': 'kube-scheduler (4000Mi Memory)',
    'spazio-mixed-pi': 'CARICO',
    'spazio-mixed-ml': 'CARICO',
}

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=False) # sharex=False allows independent x-axes

# Loop through each key to read data and plot a histogram on the appropriate subplot
for key in keys:
    # Call your actual read_df function to load the DataFrame
    df = read_df(f'{key}-pod-completion.csv')

    # Select the first row as a pandas Series.
    single_row = df.iloc[0]

    # Calculate the minimum and maximum values of the current data series.
    min_val = int(np.floor(single_row.min()))
    max_val = int(np.ceil(single_row.max()))

    # Create an array of bin edges where each bin is 2 units wide (as per your modified bins_1_wide in prompt)
    

    # Plot on the first (top) subplot for 'pi' workloads
    if 'pi' in key:
        bins_2_wide = np.arange(min_val, max_val + 2, 1)
        single_row.hist(
            ax=ax1, # Specify the subplot axis
            bins=bins_2_wide,
            color=custom_colors[key],
            edgecolor='black',
            alpha=0.7,
            label=legend_labels[key]
        )
    # Plot on the second (bottom) subplot for 'ml' pods
    elif 'ml' in key:
        bins_2_wide = np.arange(min_val, max_val + 2, 4)
        single_row.hist(
            ax=ax2, # Specify the subplot axis
            bins=bins_2_wide,
            color=custom_colors[key],
            edgecolor='black',
            alpha=0.7,
            label=legend_labels[key]
        )
    # For other keys like 'Default', you can choose to plot them on either subplot
    # or handle them separately. For this request, they are implicitly ignored if
    # they don't contain 'pi' or 'ml' in their name based on the if/elif conditions.
    # If you want to include 'Default' values, you'd need to add another condition.

# Configure the top subplot (for 'pi' workloads)
# ax1.set_title('Distribution of Pod Completion Time for "Pi" Workloads')
ax1.set_xlabel('Pod Completion Time (s)')
ax1.set_ylabel('Number of Pods')
ax1.grid(axis='y', alpha=0.75)
ax1.legend()

# Configure the bottom subplot (for 'ml' pods)
# ax2.set_title('Distribution of Pod Completion Time for "ML" Pods')
ax2.set_xlabel('Pod Completion Time (s)')
ax2.set_ylabel('Number of Pods')
ax2.grid(axis='y', alpha=0.75)
# ax2.legend()

plt.tight_layout() # Adjust layout to prevent titles/labels from overlapping
plt.savefig('../figures/mixed-pod-completion.pdf') # Uncomment to save
plt.show() # Display the plot

# %%
statistical_summary = single_row.describe()

print("\n--- Statistical Summary (using .describe()) ---")
print(statistical_summary)

# 4. Customizing Percentiles (if you need specific ones)
# You can specify the percentiles you want using the 'percentiles' argument in describe()
custom_percentiles = single_row.describe(percentiles=[.01, .10, .25, .50, .75, .90, .99])

print("\n--- Statistical Summary with Custom Percentiles ---")
print(custom_percentiles)

# 5. Extracting individual percentiles if needed
# You can also get individual percentiles using the .quantile() method
p10 = single_row.quantile(0.10)
p90 = single_row.quantile(0.90)

print(f"\nValue at 10th percentile: {p10:.2f}")
print(f"Value at 90th percentile: {p90:.2f}")
# Out:
# --- Statistical Summary (using .describe()) ---
# count    20.000000
# mean     65.250000
# std      10.527533
# min      49.000000
# 25%      58.250000
# 50%      64.000000
# 75%      72.250000
# max      82.000000
# Name: 0, dtype: float64
#
# --- Statistical Summary with Custom Percentiles ---
# count    20.000000
# mean     65.250000
# std      10.527533
# min      49.000000
# 1%       49.190000
# 10%      50.000000
# 25%      58.250000
# 50%      64.000000
# 75%      72.250000
# 90%      79.100000
# 99%      81.620000
# max      82.000000
# Name: 0, dtype: float64
#
# Value at 10th percentile: 50.00
# Value at 90th percentile: 79.10

# %% [markdown]
# ## Pod Running

# %%
def read_running(name):
    try:
        df = pd.read_csv(f'{name}-pod-running.csv')
        df['Time'] = pd.to_datetime(df['Time'], unit='ms')
        df = df.set_index('Time')
        # df = df - 1
        # df.index = pd.to_datetime(df.index, errors='coerce')
        return df
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.size'] = 20
fig, axes = plt.subplots(len(keys), 1, figsize=(14, 4 * len(keys)), sharex=True, sharey=True)


for i in range(len(keys)):
    key = keys[i]
    df = read_running(key)
    if 'spazio' in key:
        df = df - 1
# 2. Slice the DataFrame to the restricted time range
# df.loc[start_dt:end_dt] directly works because df.index is now DatetimeIndex

    df_restricted = df.loc[pd.to_datetime(experiments[key]['start'] -5, unit='s'): pd.to_datetime(experiments[key]['end']+5, unit='s')]
    
    time_elapsed_seconds = (df_restricted.index - pd.to_datetime(experiments[key]['start'], unit='s')).total_seconds()
    df_restricted.index = time_elapsed_seconds
    if df_restricted.empty:
        print(f"\nNo data found for the specified time range: {start_dt} to {end_dt}. Please check your CSV data's time range.")
    else:
        # 3. Plot the number of pods on each node as a line graph
     
        # df_restricted.plot(kind='line', marker='o', linestyle='-', ax=axes[i], markersize=4, alpha=0.6, legend=False) # Plot df_restricted directly

        for column in df_restricted.columns:
            axes[i].plot(df_restricted.index, df_restricted[column],
                         label=column, # Use column name as label for the legend
                         marker='o',
                         linestyle='-',
                         markersize=4,
                         alpha=0.6)
    
        # axes[i].set_title(f'No. Running Pods on Each Node with {experiments[key]['Name']}')
        axes[i].set_xlabel('Elapsed Time (s)')
        axes[i].set_ylabel('No. of Pods')
        axes[i].grid(True)
        # plt.legend(title='Node', bbox_to_anchor=(1.05, 1), loc='upper left') # Move legend outside to avoid obscuring lines
    
        # # --- Original second graph (Stacked Area Plot of Total Pods by Node) ---
        # plt.figure(figsize=(12, 6))
        # df_restricted.plot(kind='area', stacked=True, ax=plt.gca(), cmap='viridis', legend=False)
        # plt.title('Running Pods Over Time (Stacked by Node)')
        # plt.xlabel('Elapsed Time (s)')
        # plt.ylabel('Total Pods')
        # plt.grid(True)
        # plt.xticks(rotation=45)
        # # plt.legend(title='Node', bbox_to_anchor=(1.05, 1), loc='upper left')
        # plt.tight_layout()
        # plt.show()

for ax in axes:
    ax.tick_params(axis='x', labelbottom=True, bottom=True)
    # Re-set xlabel in case it was cleared by shared axis logic
    ax.set_xlabel('Elapsed Time (s)')

# plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(f'../figures/mixed-running-pods.pdf')    
plt.show()

# %% [markdown]
# ## Resource Utilisation

# %%
def read_df(filepath):
    try:
        df = pd.read_csv(filepath)
        df['Time'] = pd.to_datetime(df['Time'], unit='ms')
        df = df.set_index('Time')
    
        # df.index = pd.to_datetime(df.index, errors='coerce')
        # df.info()

        return df
    except FileNotFoundError:
        print(f"Error: The file '{filepath}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
plt.rcParams['font.size'] = 20
fig, axes = plt.subplots(len(keys), 1, figsize=(14, 4 * len(keys)), sharex=True, sharey=True)


for i in range(len(keys)):
    key = keys[i]
    df = read_running(key)
# 2. Slice the DataFrame to the restricted time range
# df.loc[start_dt:end_dt] directly works because df.index is now DatetimeIndex

    cpu = read_df(f'{key}-cpu-util.csv')
    mem = read_df(f'{key}-mem-util.csv')
    mem = mem.drop(columns=[experiments[key]['drop']])
    
    # Calculate the mean CPU utilization across all machines for each time point
    cpu_mean = cpu.loc[pd.to_datetime(experiments[key]['start'], unit='s'): pd.to_datetime(experiments[key]['end'], unit='s')].mean(axis=1)
    cpu_time = (cpu_mean.index - pd.to_datetime(experiments[key]['start'], unit='s')).total_seconds()
    cpu_mean.index = cpu_time
    
    # Calculate the standard deviation of CPU utilization across all machines for each time point
    cpu_std = cpu.loc[pd.to_datetime(experiments[key]['start'], unit='s'): pd.to_datetime(experiments[key]['end'], unit='s')].std(axis=1)
    cpu_std.index = cpu_time
    
    mem_mean = mem.loc[pd.to_datetime(experiments[key]['start'], unit='s'): pd.to_datetime(experiments[key]['end'], unit='s')].mean(axis=1)
    mem_time = (mem_mean.index - pd.to_datetime(experiments[key]['start'], unit='s')).total_seconds()
    mem_mean.index = mem_time
    
    # Calculate the standard deviation of mem utilization across all machines for each time point
    mem_std = mem.loc[pd.to_datetime(experiments[key]['start'], unit='s'): pd.to_datetime(experiments[key]['end'], unit='s')].std(axis=1)
    mem_std.index = mem_time
    
    # Plot the mean and standard deviation over time
    axes[i].plot(cpu_mean.index, cpu_mean, label='Mean CPU Utilisation')
    axes[i].fill_between(cpu_mean.index, cpu_mean - cpu_std,
                     cpu_mean + cpu_std, color='lightblue', alpha=0.5, label='Std Dev')
    axes[i].plot(mem_mean.index, mem_mean, label='Mean Mem Utilisation')
    axes[i].fill_between(mem_mean.index, mem_mean - mem_std,
                     mem_mean + mem_std, color='orange', alpha=0.25, label='Std Dev')
    # axes[i].tick_params(axis='x', labelbottom=False)
    # axes[i].set_title(f'Resource Utilisation With {experiments[key]['Name']}')
    axes[i].set_ylabel('Utilisation (%)')
    axes[i].grid(True)

for ax in axes:
    ax.tick_params(axis='x', labelbottom=True, bottom=True)
    # Re-set xlabel in case it was cleared by shared axis logic
    ax.set_xlabel('Elapsed Time (s)')

axes[len(keys)-1].set_xlabel('Elapsed Time (s)')
axes[len(keys)-1].legend(
    loc="upper right"
)
plt.tight_layout()
plt.savefig(f'../figures/mixed-util.pdf')
plt.show()

# %%
read_df(f'{key}-mem-util.csv')
# Out:
#                      10.244.1.173:32000  10.244.20.254:32000  \
# Time
# 2025-05-27 19:40:40           10.069017            10.506635
# 2025-05-27 19:40:45           10.090730            10.506610
# 2025-05-27 19:40:50           10.554968            10.752503
# 2025-05-27 19:40:55           11.613309            11.716919
# 2025-05-27 19:41:00           12.326443            14.357580
# 2025-05-27 19:41:05           13.278676            18.876802
# 2025-05-27 19:41:10           14.255183            20.440859
# 2025-05-27 19:41:15           15.097296            21.109333
# 2025-05-27 19:41:20           15.420394            21.220905
# 2025-05-27 19:41:25           19.011695            20.939069
# 2025-05-27 19:41:30           20.220531            20.590664
# 2025-05-27 19:41:35           20.211176            20.150825
# 2025-05-27 19:41:40           19.897014            19.352536
# 2025-05-27 19:41:45           18.256807            17.362919
# 2025-05-27 19:41:50           16.730512            17.051934
# 2025-05-27 19:41:55           16.536663            17.015597
# 2025-05-27 19:42:00           16.493654            17.071876
# 2025-05-27 19:42:05           16.993096            17.349083
# 2025-05-27 19:42:10           10.418629            10.506857
# 2025-05-27 19:42:15           10.251836            10.432262
# 2025-05-27 19:42:20           10.183740            10.441198
# 2025-05-27 19:42:25           10.148117            10.446614
# 2025-05-27 19:42:30           10.154346            10.430760
# 2025-05-27 19:42:35           10.153730            10.417343
# 2025-05-27 19:42:40           10.064684            10.413330
#
#                      10.244.21.15:32000  10.244.22.190:32000  \
# Time
# 2025-05-27 19:40:40           13.123581            10.640630
# 2025-05-27 19:40:45           13.059154            10.640630
# 2025-05-27 19:40:50           13.069617            10.640630
# 2025-05-27 19:40:55           13.427697            11.273825
# 2025-05-27 19:41:00           19.469022            12.358159
# 2025-05-27 19:41:05           21.503370            13.188723
# 2025-05-27 19:41:10           22.370591            14.122094
# 2025-05-27 19:41:15           23.073039            14.972772
# 2025-05-27 19:41:20           23.274494            15.673816
# 2025-05-27 19:41:25           22.928896            16.389213
# 2025-05-27 19:41:30           22.403236            19.492927
# 2025-05-27 19:41:35           22.133931            20.472730
# 2025-05-27 19:41:40           20.851662            19.401567
# 2025-05-27 19:41:45           19.576705            17.172583
# 2025-05-27 19:41:50           19.577049            16.988533
# 2025-05-27 19:41:55           19.927424            17.012019
# 2025-05-27 19:42:00           13.207088            17.001088
# 2025-05-27 19:42:05           13.177300            16.979768
# 2025-05-27 19:42:10           13.180352            13.960521
# 2025-05-27 19:42:15           13.181903            10.617119
# 2025-05-27 19:42:20           13.124566            10.496708
# 2025-05-27 19:42:25           13.100120            10.480115
# 2025-05-27 19:42:30           13.070528            10.470268
# 2025-05-27 19:42:35           13.005731            10.465640
# 2025-05-27 19:42:40           12.979488            10.459362
#
#                      10.244.23.28:32000  10.244.24.156:32000  \
# Time
# 2025-05-27 19:40:40           22.602563            11.402477
# 2025-05-27 19:40:45           22.617580            11.399375
# 2025-05-27 19:40:50           22.619451            11.380369
# 2025-05-27 19:40:55           26.858311            12.572016
# 2025-05-27 19:41:00           32.114466            13.748005
# 2025-05-27 19:41:05           33.249096            14.483540
# 2025-05-27 19:41:10           34.893359            15.295418
# 2025-05-27 19:41:15           36.450865            15.942153
# 2025-05-27 19:41:20           36.978027            16.427069
# 2025-05-27 19:41:25           36.779378            18.865607
# 2025-05-27 19:41:30           36.405370            20.936266
# 2025-05-27 19:41:35           35.625398            20.504773
# 2025-05-27 19:41:40           34.814653            18.870137
# 2025-05-27 19:41:45           34.088891            18.098584
# 2025-05-27 19:41:50           34.480330            18.067565
# 2025-05-27 19:41:55           31.475166            18.088540
# 2025-05-27 19:42:00           27.837768            18.138787
# 2025-05-27 19:42:05           27.822455            15.203984
# 2025-05-27 19:42:10           27.818073            11.615503
# 2025-05-27 19:42:15           27.844243            11.584188
# 2025-05-27 19:42:20           27.792076            11.596621
# 2025-05-27 19:42:25           27.801726            11.620599
# 2025-05-27 19:42:30           27.812042            11.604228
# 2025-05-27 19:42:35           27.800963            11.610875
# 2025-05-27 19:42:40           27.802022            11.615331
#
#                      10.244.25.199:32000  10.244.26.148:32000  \
# Time
# 2025-05-27 19:40:40            10.460913            10.849865
# 2025-05-27 19:40:45            10.464015            10.865473
# 2025-05-27 19:40:50            10.404462            10.880417
# 2025-05-27 19:40:55            11.315751            11.698597
# 2025-05-27 19:41:00            12.402571            12.732364
# 2025-05-27 19:41:05            16.818786            13.708277
# 2025-05-27 19:41:10            19.848767            14.480051
# 2025-05-27 19:41:15            20.857964            15.521155
# 2025-05-27 19:41:20            21.285445            15.917197
# 2025-05-27 19:41:25            20.934947            19.318281
# 2025-05-27 19:41:30            20.622757            20.445723
# 2025-05-27 19:41:35            20.037691            19.943795
# 2025-05-27 19:41:40            19.080390            18.599290
# 2025-05-27 19:41:45            17.275711            17.474409
# 2025-05-27 19:41:50            17.137378            17.340852
# 2025-05-27 19:41:55            17.020832            17.357716
# 2025-05-27 19:42:00            16.458638            17.304958
# 2025-05-27 19:42:05            10.657469            17.502326
# 2025-05-27 19:42:10            10.527630            10.935760
# 2025-05-27 19:42:15            10.526399            10.855823
# 2025-05-27 19:42:20            10.400695            10.879801
# 2025-05-27 19:42:25            10.432453            10.902032
# 2025-05-27 19:42:30            10.444443            10.893883
# 2025-05-27 19:42:35            10.444123            10.856143
# 2025-05-27 19:42:40            10.434989            10.866827
#
#                      10.244.28.200:32000  10.244.29.56:32000  \
# Time
# 2025-05-27 19:40:40            10.978799           10.686465
# 2025-05-27 19:40:45            10.978799           10.686465
# 2025-05-27 19:40:50            11.562658           10.686465
# 2025-05-27 19:40:55            12.443715           11.597950
# 2025-05-27 19:41:00            13.418866           12.465835
# 2025-05-27 19:41:05            14.357999           13.217249
# 2025-05-27 19:41:10            15.031421           15.636043
# 2025-05-27 19:41:15            15.751693           20.054693
# 2025-05-27 19:41:20            15.523920           21.295627
# 2025-05-27 19:41:25            15.185855           20.868171
# 2025-05-27 19:41:30            14.644684           20.631141
# 2025-05-27 19:41:35            13.945462           19.890757
# 2025-05-27 19:41:40            11.891762           18.491278
# 2025-05-27 19:41:45            10.851273           17.127226
# 2025-05-27 19:41:50            10.860530           17.010336
# 2025-05-27 19:41:55            10.843839           17.024271
# 2025-05-27 19:42:00            10.833302           17.450520
# 2025-05-27 19:42:05            10.852307           10.693136
# 2025-05-27 19:42:10            10.852012           10.515217
# 2025-05-27 19:42:15            10.854252           10.517851
# 2025-05-27 19:42:20            10.839112           10.537472
# 2025-05-27 19:42:25            10.847753           10.581860
# 2025-05-27 19:42:30            10.820697           10.588950
# 2025-05-27 19:42:35            10.857379           10.607045
# 2025-05-27 19:42:40            10.783227           10.588408
#
#                      10.244.30.88:32000  10.244.31.26:32000  \
# Time
# 2025-05-27 19:40:40           12.590960           10.600698
# 2025-05-27 19:40:45           12.626608           10.605327
# 2025-05-27 19:40:50           12.907656           10.822809
# 2025-05-27 19:40:55           13.706782           11.735107
# 2025-05-27 19:41:00           14.706674           13.073162
# 2025-05-27 19:41:05           15.903172           17.736771
# 2025-05-27 19:41:10           18.794058           21.155162
# 2025-05-27 19:41:15           21.589473           25.356701
# 2025-05-27 19:41:20           22.776640           26.577768
# 2025-05-27 19:41:25           23.166282           27.239398
# 2025-05-27 19:41:30           22.694758           27.007194
# 2025-05-27 19:41:35           22.024831           26.627991
# 2025-05-27 19:41:40           21.405349           26.255188
# 2025-05-27 19:41:45           20.014904           25.262707
# 2025-05-27 19:41:50           19.110902           23.880732
# 2025-05-27 19:41:55           19.126412           23.620733
# 2025-05-27 19:42:00           19.236212           23.614627
# 2025-05-27 19:42:05           16.198179           23.547000
# 2025-05-27 19:42:10           12.726068           23.559875
# 2025-05-27 19:42:15           12.714399           24.328671
# 2025-05-27 19:42:20           12.727890           14.241323
# 2025-05-27 19:42:25           12.734094           10.888738
# 2025-05-27 19:42:30           12.737171           10.803114
# 2025-05-27 19:42:35           12.716688           10.794891
# 2025-05-27 19:42:40           12.714891           10.718598
#
#                      10.244.32.247:32000  10.244.33.120:32000  \
# Time
# 2025-05-27 19:40:40            10.944617            11.042501
# 2025-05-27 19:40:45            10.944617            11.042501
# 2025-05-27 19:40:50            10.967882            11.081473
# 2025-05-27 19:40:55            11.830228            12.226910
# 2025-05-27 19:41:00            12.925591            12.999890
# 2025-05-27 19:41:05            13.862852            13.981957
# 2025-05-27 19:41:10            17.223781            14.769709
# 2025-05-27 19:41:15            20.795595            15.690229
# 2025-05-27 19:41:20            21.804201            15.825854
# 2025-05-27 19:41:25            21.384402            15.382568
# 2025-05-27 19:41:30            20.864281            14.691002
# 2025-05-27 19:41:35            20.326238            13.740472
# 2025-05-27 19:41:40            19.199019            11.318872
# 2025-05-27 19:41:45            17.744739            11.037085
# 2025-05-27 19:41:50            17.414601            10.952249
# 2025-05-27 19:41:55            17.406206            10.971402
# 2025-05-27 19:42:00            17.438358            11.024604
# 2025-05-27 19:42:05            17.070135            11.025564
# 2025-05-27 19:42:10            11.054983            10.954859
# 2025-05-27 19:42:15            10.935705            10.973126
# 2025-05-27 19:42:20            10.887477            10.970467
# 2025-05-27 19:42:25            10.887502            10.968325
# 2025-05-27 19:42:30            10.890185            10.985361
# 2025-05-27 19:42:35            10.891170            10.986518
# 2025-05-27 19:42:40            10.894272            10.996957
#
#                      10.244.34.173:32000  10.244.36.32:32000  \
# Time
# 2025-05-27 19:40:40            12.281970           11.260038
# 2025-05-27 19:40:45            12.143809           11.259989
# 2025-05-27 19:40:50            12.211954           11.113630
# 2025-05-27 19:40:55            13.340381           14.312151
# 2025-05-27 19:41:00            14.360362           19.131154
# 2025-05-27 19:41:05            15.001706           20.260737
# 2025-05-27 19:41:10            15.855855           23.194483
# 2025-05-27 19:41:15            16.902941           26.897345
# 2025-05-27 19:41:20            17.350856           27.854055
# 2025-05-27 19:41:25            17.840696           27.685269
# 2025-05-27 19:41:30            20.383423           27.187502
# 2025-05-27 19:41:35            21.684944           26.757879
# 2025-05-27 19:41:40            21.361626           26.132193
# 2025-05-27 19:41:45            19.630482           24.522199
# 2025-05-27 19:41:50            18.581746           23.934499
# 2025-05-27 19:41:55            18.589329           23.904169
# 2025-05-27 19:42:00            18.709444           23.989547
# 2025-05-27 19:42:05            15.535860           24.077485
# 2025-05-27 19:42:10            12.159738           21.298862
# 2025-05-27 19:42:15            12.134232           11.248738
# 2025-05-27 19:42:20            12.118427           11.128623
# 2025-05-27 19:42:25            12.126330           11.112473
# 2025-05-27 19:42:30            12.148955           11.082955
# 2025-05-27 19:42:35            12.155848           11.055136
# 2025-05-27 19:42:40            12.123449           11.047110
#
#                      10.244.37.129:32000  10.244.38.32:32000  \
# Time
# 2025-05-27 19:40:40            10.324968           10.608428
# 2025-05-27 19:40:45            10.331172           10.583859
# 2025-05-27 19:40:50            10.436491           10.589718
# 2025-05-27 19:40:55            11.678188           11.635425
# 2025-05-27 19:41:00            13.576887           12.529210
# 2025-05-27 19:41:05            18.659212           13.353792
# 2025-05-27 19:41:10            24.452331           14.028445
# 2025-05-27 19:41:15            26.306740           15.075063
# 2025-05-27 19:41:20            27.219432           15.159062
# 2025-05-27 19:41:25            27.166674           14.831460
# 2025-05-27 19:41:30            27.216355           14.606764
# 2025-05-27 19:41:35            26.803621           14.048657
# 2025-05-27 19:41:40            26.297287           13.467530
# 2025-05-27 19:41:45            24.575818           10.929876
# 2025-05-27 19:41:50            23.621742           10.570959
# 2025-05-27 19:41:55            23.521101           10.546931
# 2025-05-27 19:42:00            23.480504           10.550747
# 2025-05-27 19:42:05            23.531564           10.549565
# 2025-05-27 19:42:10            23.566892           10.573642
# 2025-05-27 19:42:15            24.512154           10.523666
# 2025-05-27 19:42:20            10.653382           10.510987
# 2025-05-27 19:42:25            10.560077           10.546635
# 2025-05-27 19:42:30            10.461257           10.509018
# 2025-05-27 19:42:35            10.455718           10.500721
# 2025-05-27 19:42:40            10.474084           10.492696
#
#                      10.244.39.131:32000
# Time
# 2025-05-27 19:40:40            12.068421
# 2025-05-27 19:40:45            12.069898
# 2025-05-27 19:40:50            12.120735
# 2025-05-27 19:40:55            13.281880
# 2025-05-27 19:41:00            14.379041
# 2025-05-27 19:41:05            14.981314
# 2025-05-27 19:41:10            17.886650
# 2025-05-27 19:41:15            25.429745
# 2025-05-27 19:41:20            28.272796
# 2025-05-27 19:41:25            28.880166
# 2025-05-27 19:41:30            28.428263
# 2025-05-27 19:41:35            27.895833
# 2025-05-27 19:41:40            26.893036
# 2025-05-27 19:41:45            25.388386
# 2025-05-27 19:41:50            25.221200
# 2025-05-27 19:41:55            25.164847
# 2025-05-27 19:42:00            25.203499
# 2025-05-27 19:42:05            25.190131
# 2025-05-27 19:42:10            22.272855
# 2025-05-27 19:42:15            12.506167
# 2025-05-27 19:42:20            12.415028
# 2025-05-27 19:42:25            12.409809
# 2025-05-27 19:42:30            12.398583
# 2025-05-27 19:42:35            12.423374
# 2025-05-27 19:42:40            12.431868
